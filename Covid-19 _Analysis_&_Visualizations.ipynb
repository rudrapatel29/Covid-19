# %% [markdown]
# # **COVID-19 - Analysis & Visualizations**

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Importing Datasets

# %%
covid_cases = pd.read_csv("C:\\Users\\rudyr\\Downloads\\WHO-COVID-19-global-data.csv", encoding='latin1')
covid_vacc = pd.read_csv("C:\\Users\\rudyr\\Downloads\\vaccination-data.csv")
cov_vaccines = pd.read_csv(r"C:\Users\rudyr\Downloads\Vaccination C19 WHO.csv")

# %% [markdown]
# ### Structure of dataframe

# %%
covid_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57840 entries, 0 to 57839
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_reported      57840 non-null  object
#  1   Country_code       57599 non-null  object
#  2   Country            57840 non-null  object
#  3   WHO_region         53502 non-null  object
#  4   New_cases          39028 non-null  float64
#  5   Cumulative_cases   57840 non-null  int64
#  6   New_deaths         25001 non-null  float64
#  7   Cumulative_deaths  57840 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 3.5+ MB

# %%
covid_vacc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 16 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   COUNTRY                               215 non-null    object
#  1   ISO3                                  215 non-null    object
#  2   WHO_REGION                            209 non-null    object
#  3   DATA_SOURCE                           215 non-null    object
#  4   DATE_UPDATED                          208 non-null    object
#  5   TOTAL_VACCINATIONS                    209 non-null    float64
#  6   PERSONS_VACCINATED_1PLUS_DOSE         209 non-null    float64
#  7   TOTAL_VACCINATIONS_PER100             207 non-null    float64
#  8   PERSONS_VACCINATED_1PLUS_DOSE_PER100  207 non-null    float64
#  9   PERSONS_LAST_DOSE                     209 non-null    float64
#  10  PERSONS_LAST_DOSE_PER100              207 non-null    float64
#  11  VACCINES_USED                         0 non-null      float64
#  12  FIRST_VACCINE_DATE                    196 non-null    object
#  13  NUMBER_VACCINES_TYPES_USED            0 non-null      float64
#  14  PERSONS_BOOSTER_ADD_DOSE              195 non-null    float64
#  15  PERSONS_BOOSTER_ADD_DOSE_PER100       184 non-null    float64
# dtypes: float64(10), object(6)
# memory usage: 27.0+ KB

# %%
cov_vaccines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1105 entries, 0 to 1104
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ISO3                1105 non-null   object
#  1   PRODUCT_NAME        1098 non-null   object
#  2   VACCINE_NAME        1105 non-null   object
#  3   COMPANY_NAME        1054 non-null   object
#  4   AUTHORIZATION_DATE  177 non-null    object
#  5   START_DATE          310 non-null    object
#  6   END_DATE            0 non-null      float64
#  7   COMMENT             0 non-null      float64
#  8   DATA_SOURCE         1105 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 77.8+ KB

# %%
covid_cases.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-05           AF  Afghanistan       EMRO        NaN
# 1    2020-01-12           AF  Afghanistan       EMRO        NaN
# 2    2020-01-19           AF  Afghanistan       EMRO        NaN
# 3    2020-01-26           AF  Afghanistan       EMRO        NaN
# 4    2020-02-02           AF  Afghanistan       EMRO        NaN
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0         NaN                  0
# 1                 0         NaN                  0
# 2                 0         NaN                  0
# 3                 0         NaN                  0
# 4                 0         NaN                  0

# %%
cov_vaccines.head(20)
# Out:
#    ISO3  PRODUCT_NAME                 VACCINE_NAME  \
# 0   SHN       AZD1222        AstraZeneca - AZD1222
# 1   GRL     mRNA-1273          Moderna - mRNA-1273
# 2   FRO     mRNA-1273          Moderna - mRNA-1273
# 3   FRO     Comirnaty  Pfizer BioNTech - Comirnaty
# 4   JEY     mRNA-1273          Moderna - mRNA-1273
# 5   JEY       AZD1222        AstraZeneca - AZD1222
# 6   JEY     Comirnaty  Pfizer BioNTech - Comirnaty
# 7   BIH       AZD1222        AstraZeneca - AZD1222
# 8   BIH     Comirnaty  Pfizer BioNTech - Comirnaty
# 9   BIH     Coronavac          Sinovac - CoronaVac
# 10  GGY     mRNA-1273          Moderna - mRNA-1273
# 11  GGY       AZD1222        AstraZeneca - AZD1222
# 12  GGY     Comirnaty  Pfizer BioNTech - Comirnaty
# 13  TUR     Comirnaty  Pfizer BioNTech - Comirnaty
# 14  TUR     Coronavac          Sinovac - CoronaVac
# 15  TUR           NaN                     Turkovac
# 16  RUS  EpiVacCorona         SRCVB - EpiVacCorona
# 17  GIB       AZD1222        AstraZeneca - AZD1222
# 18  GIB     Comirnaty  Pfizer BioNTech - Comirnaty
# 19  IMN     mRNA-1273          Moderna - mRNA-1273
#
#                                          COMPANY_NAME AUTHORIZATION_DATE  \
# 0                                         AstraZeneca                NaN
# 1                                             Moderna                NaN
# 2                                             Moderna                NaN
# 3                                     Pfizer BioNTech                NaN
# 4                                             Moderna                NaN
# 5                                         AstraZeneca                NaN
# 6                                     Pfizer BioNTech                NaN
# 7                                         AstraZeneca                NaN
# 8                                     Pfizer BioNTech                NaN
# 9                                             Sinovac                NaN
# 10                                            Moderna                NaN
# 11                                        AstraZeneca                NaN
# 12                                    Pfizer BioNTech                NaN
# 13                                    Pfizer BioNTech                NaN
# 14                                            Sinovac                NaN
# 15                                                NaN                NaN
# 16  State Research Center of Virology & Biotechnology                NaN
# 17                                        AstraZeneca                NaN
# 18                                    Pfizer BioNTech                NaN
# 19                                            Moderna                NaN
#
#    START_DATE  END_DATE  COMMENT DATA_SOURCE
# 0         NaN       NaN      NaN        OWID
# 1         NaN       NaN      NaN        OWID
# 2         NaN       NaN      NaN        OWID
# 3         NaN       NaN      NaN        OWID
# 4         NaN       NaN      NaN        OWID
# 5         NaN       NaN      NaN        OWID
# 6         NaN       NaN      NaN        OWID
# 7         NaN       NaN      NaN        OWID
# 8         NaN       NaN      NaN        OWID
# 9         NaN       NaN      NaN        OWID
# 10        NaN       NaN      NaN        OWID
# 11        NaN       NaN      NaN        OWID
# 12        NaN       NaN      NaN        OWID
# 13        NaN       NaN      NaN        OWID
# 14        NaN       NaN      NaN        OWID
# 15        NaN       NaN      NaN        OWID
# 16        NaN       NaN      NaN        OWID
# 17        NaN       NaN      NaN        OWID
# 18        NaN       NaN      NaN        OWID
# 19        NaN       NaN      NaN        OWID

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Countries with most Covid Cases

# %%
total_cases_country = covid_cases.groupby('Country')['New_cases'].sum().sort_values(ascending=False)
total_cases_country
# Out:
# Country
# United States of America                     103436829.0
# China                                         99375079.0
# India                                         45042054.0
# France                                        38997490.0
# Germany                                       38437756.0
#                                                 ...
# International conveyance (American Samoa)            4.0
# Pitcairn                                             4.0
# International conveyance (Kiribati)                  2.0
# Democratic People's Republic of Korea                0.0
# Turkmenistan                                         0.0
# Name: New_cases, Length: 240, dtype: float64

# %% [markdown]
# ### Countries with most Deaths

# %%
country_deaths = covid_cases.groupby('Country')['New_deaths'].sum().sort_values(ascending=False)
country_deaths
# Out:
# Country
# United States of America    1194158.0
# Brazil                       702116.0
# India                        533626.0
# Russian Federation           403202.0
# Mexico                       334586.0
#                               ...
# Niue                              0.0
# Pitcairn                          0.0
# Saint Helena                      0.0
# Turkmenistan                      0.0
# Tokelau                           0.0
# Name: New_deaths, Length: 240, dtype: float64

# %% [markdown]
# ### Top 10 Countries with Highest Death Ratio Per 1000 People

# %%
covid_cases = covid_cases.dropna(subset=['New_cases', 'New_deaths'])
country_agg = covid_cases.groupby('Country').agg({
    'New_cases': 'sum',
    'New_deaths': 'sum'
}).reset_index()

# Rename columns
country_agg = country_agg.rename(columns={
    'New_cases': 'Cases',
    'New_deaths': 'Deaths'
}).reset_index(drop=True)

top10_cases = country_agg.sort_values('Cases', ascending=False).head(10)
top10_cases['Death_Ratio_Per_1000'] = (top10_cases['Deaths'] / top10_cases['Cases']) * 1000
top10_cases_sorted = top10_cases.sort_values('Death_Ratio_Per_1000', ascending=False).reset_index(drop=True)

print(top10_cases_sorted[['Country', 'Cases', 'Deaths',  'Death_Ratio_Per_1000']])
# Out:
#                                              Country        Cases     Deaths  \
# 0                                             Brazil   37511837.0   702116.0
# 1                                              India   45040782.0   533626.0
# 2                           United States of America  103436789.0  1127152.0
# 3  United Kingdom of Great Britain and Northern I...   24793255.0   232112.0
# 4                                              Italy   26781075.0   197307.0
# 5                                            Germany   38437742.0   174979.0
# 6                                             France   38997474.0   151365.0
# 7                                              Japan   31666650.0    74694.0
# 8                                              China   96048177.0   122309.0
# 9                                  Republic of Korea   33340243.0    35934.0
#
#    Death_Ratio_Per_1000
# 0             18.717185
# 1             11.847618
# 2             10.897013
# 3              9.361901
# 4              7.367404
# 5              4.552271
# 6              3.881405
# 7              2.358759
# 8              1.273413
# 9              1.077797

# %% [markdown]
# ### Total Cases by WHO Region

# %%
region_agg = covid_cases.groupby('WHO_region').agg({'New_cases': 'sum'}).reset_index()
region_agg = region_agg.rename(columns={'New_cases': 'Total_Cases'})
region_agg_sorted = region_agg.sort_values('Total_Cases', ascending=False).reset_index(drop=True)
region_agg_sorted['Total_Cases'] = region_agg_sorted['Total_Cases'].astype(int)
print(region_agg_sorted)
# Out:
#   WHO_region  Total_Cases
# 0       EURO    278800764
# 1       WPRO    200156036
# 2       AMRO    192418516
# 3      SEARO     61227274
# 4       EMRO     23067888
# 5       AFRO      8581118
# 6      OTHER          341

# %%
covid_vacc.head()
# Out:
#        COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  TOTAL_VACCINATIONS  \
# 0        Aruba  ABW       AMRO   REPORTING   2023-12-29            217124.0
# 1  Afghanistan  AFG       EMRO   REPORTING   2023-12-31          22964750.0
# 2       Angola  AGO       AFRO   REPORTING   2023-12-31          27819132.0
# 3     Anguilla  AIA       AMRO   REPORTING   2023-12-29             24864.0
# 4      Albania  ALB       EURO   REPORTING   2023-12-23           3088966.0
#
#    PERSONS_VACCINATED_1PLUS_DOSE  TOTAL_VACCINATIONS_PER100  \
# 0                        90493.0                      203.0
# 1                     19151369.0                       59.0
# 2                     16550642.0                       85.0
# 3                        10858.0                      166.0
# 4                      1349255.0                      107.0
#
#    PERSONS_VACCINATED_1PLUS_DOSE_PER100  PERSONS_LAST_DOSE  \
# 0                                  85.0            84363.0
# 1                                  49.0         18370386.0
# 2                                  50.0          9609080.0
# 3                                  72.0            10382.0
# 4                                  47.0          1279333.0
#
#    PERSONS_LAST_DOSE_PER100  VACCINES_USED FIRST_VACCINE_DATE  \
# 0                      79.0            NaN         2021-02-17
# 1                      47.0            NaN         2021-02-22
# 2                      29.0            NaN         2021-03-10
# 3                      69.0            NaN         2021-02-05
# 4                      44.0            NaN         2021-01-13
#
#    NUMBER_VACCINES_TYPES_USED  PERSONS_BOOSTER_ADD_DOSE  \
# 0                         NaN                   35659.0
# 1                         NaN                 2729940.0
# 2                         NaN                 3067091.0
# 3                         NaN                    3231.0
# 4                         NaN                  402371.0
#
#    PERSONS_BOOSTER_ADD_DOSE_PER100
# 0                             33.0
# 1                              7.0
# 2                              9.0
# 3                             22.0
# 4                             14.0

# %% [markdown]
# ### Join the datasets on the 'Country' and 'WHO_region' columns

# %%
merged_data = covid_cases.merge(covid_vacc, left_on=['Country', 'WHO_region'], right_on=['COUNTRY', 'WHO_REGION'])
merged_data['Vaccination_to_Cases_Ratio'] = ((merged_data['TOTAL_VACCINATIONS'] / merged_data['Cumulative_cases']) * 100).round(2)
merged_data[['Country', 'WHO_region', 'TOTAL_VACCINATIONS', 'Cumulative_cases', 'Vaccination_to_Cases_Ratio']]
# Out:
#            Country WHO_region  TOTAL_VACCINATIONS  Cumulative_cases  \
# 0      Afghanistan       EMRO          22964750.0                91
# 1      Afghanistan       EMRO          22964750.0               274
# 2      Afghanistan       EMRO          22964750.0               521
# 3      Afghanistan       EMRO          22964750.0               908
# 4      Afghanistan       EMRO          22964750.0              1330
# ...            ...        ...                 ...               ...
# 23719     Zimbabwe       AFRO          13935112.0            266048
# 23720     Zimbabwe       AFRO          13935112.0            266117
# 23721     Zimbabwe       AFRO          13935112.0            266202
# 23722     Zimbabwe       AFRO          13935112.0            266355
# 23723     Zimbabwe       AFRO          13935112.0            266358
#
#        Vaccination_to_Cases_Ratio
# 0                     25235989.01
# 1                      8381295.62
# 2                      4407821.50
# 3                      2529157.49
# 4                      1726672.93
# ...                           ...
# 23719                     5237.82
# 23720                     5236.46
# 23721                     5234.79
# 23722                     5231.78
# 23723                     5231.72
#
# [23724 rows x 5 columns]

# %% [markdown]
# ### Top 10 Countries with most Vaccinations

# %%
# Disabled scientific notation : Set display.float_format, it ensures all floating-point numbers are displayed in two decimal places ({:.2f}). 
# Useful for avoiding scientific notation (e+10) and for making the data more readable.
pd.set_option('display.float_format', '{:.2f}'.format)

# Group by 'COUNTRY' and sum the 'TOTAL_VACCINATIONS'
highest_vacc = merged_data[['COUNTRY', 'TOTAL_VACCINATIONS']].groupby('COUNTRY').sum()
highest_vacc_sorted = highest_vacc.sort_values(by='TOTAL_VACCINATIONS', ascending=False)
print(highest_vacc_sorted.head(10))
# Out:
#                           TOTAL_VACCINATIONS
# COUNTRY
# China                        692825501249.00
# India                        494673778144.00
# United States of America     119584716720.00
# Indonesia                     86502572980.00
# Brazil                        85179122490.00
# Japan                         71503839660.00
# Bangladesh                    63027995466.00
# Pakistan                      50464173312.00
# Mexico                        43778579721.00
# Russian Federation            42721387824.00

# %% [markdown]
# ### Top 20 Countries by Percentage of Population with At Least One COVID-19 Vaccine Dose

# %%
country_one_plus_dose = merged_data[['COUNTRY', 'PERSONS_VACCINATED_1PLUS_DOSE_PER100']].groupby('COUNTRY').mean()
country_one_plus_dose = country_one_plus_dose.sort_values(by='PERSONS_VACCINATED_1PLUS_DOSE_PER100', ascending=False).head(20)
country_one_plus_dose
# Out:
#                       PERSONS_VACCINATED_1PLUS_DOSE_PER100
# COUNTRY
# Brunei Darussalam                                   100.00
# Puerto Rico                                         100.00
# United Arab Emirates                                100.00
# Palau                                               100.00
# Nauru                                               100.00
# Qatar                                                99.00
# Nicaragua                                            97.00
# Nepal                                                96.00
# Samoa                                                96.00
# Cayman Islands                                       95.00
# Cuba                                                 95.00
# Portugal                                             95.00
# Peru                                                 93.00
# Viet Nam                                             93.00
# Chile                                                92.00
# Bangladesh                                           92.00
# Cambodia                                             92.00
# Bhutan                                               91.00
# Costa Rica                                           91.00
# Argentina                                            91.00

# %% [markdown]
# ### Total Cases by WHO Region

# %%
region_vacc = merged_data[['WHO_REGION','TOTAL_VACCINATIONS']].groupby('WHO_REGION').sum()
region_vacc = region_vacc.sort_values(by='TOTAL_VACCINATIONS',ascending=False)
region_agg
# Out:
#   WHO_region  Total_Cases
# 0       AFRO   8581118.00
# 1       AMRO 192418516.00
# 2       EMRO  23067888.00
# 3       EURO 278800764.00
# 4      OTHER       341.00
# 5      SEARO  61227274.00
# 6       WPRO 200156036.00

# %%
merged_data.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-03-29           AF  Afghanistan       EMRO      67.00
# 1    2020-04-05           AF  Afghanistan       EMRO     183.00
# 2    2020-04-12           AF  Afghanistan       EMRO     247.00
# 3    2020-04-19           AF  Afghanistan       EMRO     387.00
# 4    2020-04-26           AF  Afghanistan       EMRO     422.00
#
#    Cumulative_cases  New_deaths  Cumulative_deaths      COUNTRY ISO3  ...  \
# 0                91        2.00                  2  Afghanistan  AFG  ...
# 1               274        3.00                  5  Afghanistan  AFG  ...
# 2               521       10.00                 15  Afghanistan  AFG  ...
# 3               908       15.00                 30  Afghanistan  AFG  ...
# 4              1330       13.00                 43  Afghanistan  AFG  ...
#
#   TOTAL_VACCINATIONS_PER100 PERSONS_VACCINATED_1PLUS_DOSE_PER100  \
# 0                     59.00                                49.00
# 1                     59.00                                49.00
# 2                     59.00                                49.00
# 3                     59.00                                49.00
# 4                     59.00                                49.00
#
#   PERSONS_LAST_DOSE  PERSONS_LAST_DOSE_PER100  VACCINES_USED  \
# 0       18370386.00                     47.00            NaN
# 1       18370386.00                     47.00            NaN
# 2       18370386.00                     47.00            NaN
# 3       18370386.00                     47.00            NaN
# 4       18370386.00                     47.00            NaN
#
#    FIRST_VACCINE_DATE  NUMBER_VACCINES_TYPES_USED  PERSONS_BOOSTER_ADD_DOSE  \
# 0          2021-02-22                         NaN                2729940.00
# 1          2021-02-22                         NaN                2729940.00
# 2          2021-02-22                         NaN                2729940.00
# 3          2021-02-22                         NaN                2729940.00
# 4          2021-02-22                         NaN                2729940.00
#
#    PERSONS_BOOSTER_ADD_DOSE_PER100  Vaccination_to_Cases_Ratio
# 0                             7.00                 25235989.01
# 1                             7.00                  8381295.62
# 2                             7.00                  4407821.50
# 3                             7.00                  2529157.49
# 4                             7.00                  1726672.93
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Number of Countries Vaccines exported by Company

# %%
company_vaccine_distribution = cov_vaccines.groupby('COMPANY_NAME').size().reset_index(name='Total_Vaccines')
company_vaccine_distribution
# Out:
#                                          COMPANY_NAME  Total_Vaccines
# 0              Anhui Zhifei Longcom Biopharmaceutical               3
# 1                                         AstraZeneca             147
# 2    Beijing Bio-Institute Biological Products (CNBG)             101
# 3                                      Bharat Biotech              33
# 4                                        Biological E               1
# 5                                 CanSino Biologicals              28
# 6    Center for Genetic Engineering and Biotechnology               5
# 7                                            Chumakov               1
# 8                         Gamaleya Research Institute              99
# 9                         Insitute of Medical Biology               1
# 10                        Instituto Finlay de Vacunas               6
# 11                            Janssen Pharmaceuticals             125
# 12                                            Moderna             129
# 13                                            Novavax              32
# 14                                    Pfizer BioNTech             174
# 15  Research Institute for Biological Safety Problems               3
# 16                           Serum Institute of India              92
# 17              Shenzhen GenoImmune Medical Institute               1
# 18                                            Sinovac              65
# 19  State Research Center of Virology & Biotechnology               2
# 20                                            Valneva               2
# 21      Wuhan Institute of Biological Products (CNBG)               3
# 22                                       Zydus Cadila               1

# %% [markdown]
# ## **Visualizations**

# %% [markdown]
# ### Total Covid Cases in each WHO Region

# %%
region_agg_sorted = region_agg.reset_index().sort_values(by='Total_Cases', ascending=False)

palette = ['orange', 'lightgreen', 'coral', 'yellow', 'pink', 'gray','purple']
sns.barplot(data=region_agg_sorted.reset_index(), x='WHO_region', y='Total_Cases', hue='WHO_region', palette=palette)
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('WHO Region')
plt.ylabel('Total Vaccinations')
plt.title('Total Vaccinations by WHO Region')
plt.show()

# %% [markdown]
# ### Top 20 Countries with Highest Total deaths

# %%
merged_data = covid_cases.merge(covid_vacc, left_on=['Country', 'WHO_region'], right_on=['COUNTRY', 'WHO_REGION'])
merged_data['Vaccination_to_Cases_Ratio'] = ((merged_data['TOTAL_VACCINATIONS'] / merged_data['Cumulative_cases']) * 100).round(2)
merged_data[['Country', 'WHO_region', 'TOTAL_VACCINATIONS', 'Cumulative_cases', 'Vaccination_to_Cases_Ratio']]

country_deaths = merged_data[['COUNTRY', 'Cumulative_deaths']].groupby('COUNTRY').max()
country_deaths = country_deaths.sort_values(by='Cumulative_deaths', ascending=False).head(20)
country_deaths = country_deaths.reset_index()

plt.figure(figsize=(13, 7))
sns.barplot(data=country_deaths, x='COUNTRY', y='Cumulative_deaths', palette='viridis', hue='COUNTRY', legend=False)
plt.title('Top 20 Countries with Highest Total Deaths')
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))     
plt.xlabel('Country')
plt.ylabel('Total Deaths')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# ### Total Vaccinations in each WHO Region

# %%
palette = ['orange', 'lightgreen', 'coral', 'yellow', 'pink', 'gray']
sns.barplot(data=region_vacc, x='WHO_REGION', y='TOTAL_VACCINATIONS', palette=palette, hue='WHO_REGION')
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('WHO Region')
plt.ylabel('Total Vaccinations')
plt.title('Total Vaccinations by WHO Region')
plt.show()

# %% [markdown]
# ### Person Vaccinated with 1+ Dose per 100 by each Country

# %%
# Group by COUNTRY and sort by PERSONS_VACCINATED_1PLUS_DOSE_PER100
country_one_plus_dose = merged_data[['COUNTRY', 'PERSONS_VACCINATED_1PLUS_DOSE_PER100']].groupby('COUNTRY').mean()
country_one_plus_dose = country_one_plus_dose.sort_values(by='PERSONS_VACCINATED_1PLUS_DOSE_PER100', ascending=False).head(20)
country_one_plus_dose

plt.figure(figsize = (13,7))
sns.barplot(data=country_one_plus_dose, x = 'COUNTRY', y = 'PERSONS_VACCINATED_1PLUS_DOSE_PER100', hue = 'COUNTRY').set_title('Person Vaccinated 1 Plus Dose Per 100 By Country')
plt.xlabel('Country')
plt.xticks(rotation=45, ha='right')
plt.ylabel('More than 1 Dose Vaccinated per 100')
plt.show()

# %% [markdown]
# ### Person Vaccinated per 100 by each Country

# %%
# Group by COUNTRY and sort by PERSONS_BOOSTER_ADD_DOSE_PER100
country_one_plus_dose = merged_data[['COUNTRY', 'PERSONS_BOOSTER_ADD_DOSE_PER100']].groupby('COUNTRY').mean()
country_one_plus_dose = country_one_plus_dose.sort_values(by='PERSONS_BOOSTER_ADD_DOSE_PER100', ascending=False).head(20)

plt.figure(figsize = (13,7))
sns.barplot(data=country_one_plus_dose, x = 'COUNTRY', y = 'PERSONS_BOOSTER_ADD_DOSE_PER100', palette='Set3', hue = 'COUNTRY').set_title('Person Vaccinated Per 100 By Country')
plt.xlabel('Country')
plt.xticks(rotation=45, ha='right')
plt.ylabel('More than 1 Dose Vaccinated per 100')
plt.show()

# %% [markdown]
# ### Total vaccinations by Country

# %%
country_booster_dose = merged_data[['COUNTRY', 'TOTAL_VACCINATIONS']].groupby('COUNTRY').mean()
country_booster_dose = country_booster_dose.sort_values(by='TOTAL_VACCINATIONS', ascending=False).head(15)

plt.figure(figsize=(12,6))
sns.barplot(data=country_booster_dose.reset_index(), x='COUNTRY', y='TOTAL_VACCINATIONS', palette='Set2', hue ='COUNTRY')
plt.gca().yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.0f}'))
plt.xlabel('Country')
plt.xticks(rotation = 45)
plt.ylabel('Total Vaccinations')
plt.title('Total Vaccinations by Country')
plt.show()

# %% [markdown]
# ### Top 10 Vaccine Companies with most supplies to Countries

# %%
company_vaccine_distribution = cov_vaccines.groupby('COMPANY_NAME').size().reset_index(name='Total_Vaccines')
top_10_companies = company_vaccine_distribution.sort_values(by='Total_Vaccines', ascending=False).head(10)

plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_companies, x='COMPANY_NAME', y='Total_Vaccines', palette='viridis', hue = 'COMPANY_NAME')
plt.title('Top 10 Vaccine Companies by Total Supplies to Countries')
plt.xlabel('Vaccine Company')
plt.ylabel('No. Countries Vaccimes Supplied')
plt.xticks(rotation=45, ha='right')
plt.show()
